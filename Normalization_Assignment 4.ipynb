# %% [markdown]
# # DMDD ASSIGNMENT 4 ( NORMALIZATION )
# ### Prathamesh kulkarnj - 001560684
# ### Shreyas Shetty - 002752852

# %%
import pandas as pd

# %%
df = pd.read_csv('NormalizationDataset.csv')

# %%
df
# Out:
#      index                                          job_title  \
# 0        0  Technology Lead : Data Science I Machine Learning
# 1        1                Software Engineer, Machine Learning
# 2        2        Experienced Over The Shoulder Mechanic- C17
# 3        3                                     Data Scientist
# 4        4                                   Python Developer
# ..     ...                                                ...
# 795    795                                     Java Developer
# 796    796                          Junior Frontend Developer
# 797    797                           Website Development Lead
# 798    798                           IT Application Developer
# 799    799                              Operation Engineer-12
#
#                              company          job_location  \
# 0                    Infosys Limited  Bengaluru, Karnataka
# 1                             Google  Bengaluru, Karnataka
# ...

# %%
df[['city','State']]=df['job_location'].str.split(',', expand=True)

# %%
df
# Out:
#      index                                          job_title  \
# 0        0  Technology Lead : Data Science I Machine Learning
# 1        1                Software Engineer, Machine Learning
# 2        2        Experienced Over The Shoulder Mechanic- C17
# 3        3                                     Data Scientist
# 4        4                                   Python Developer
# ..     ...                                                ...
# 795    795                                     Java Developer
# 796    796                          Junior Frontend Developer
# 797    797                           Website Development Lead
# 798    798                           IT Application Developer
# 799    799                              Operation Engineer-12
#
#                              company          job_location  \
# 0                    Infosys Limited  Bengaluru, Karnataka
# 1                             Google  Bengaluru, Karnataka
# ...

# %%
df
# Out:
#      index                                          job_title  \
# 0        0  Technology Lead : Data Science I Machine Learning
# 1        1                Software Engineer, Machine Learning
# 2        2        Experienced Over The Shoulder Mechanic- C17
# 3        3                                     Data Scientist
# 4        4                                   Python Developer
# ..     ...                                                ...
# 795    795                                     Java Developer
# 796    796                          Junior Frontend Developer
# 797    797                           Website Development Lead
# 798    798                           IT Application Developer
# 799    799                              Operation Engineer-12
#
#                              company          job_location  \
# 0                    Infosys Limited  Bengaluru, Karnataka
# 1                             Google  Bengaluru, Karnataka
# ...

# %%
for i in list:
    a=a+1
    if(i==' Maharashtra'):
        print(a)
# Out:
# 2183

# %%
df2 = df[['index' ,'job_title','job_url', 'job_summary']]

# %%
df2
# Out:
#      index                                          job_title  \
# 0        0  Technology Lead : Data Science I Machine Learning
# 1        1                Software Engineer, Machine Learning
# 2        2        Experienced Over The Shoulder Mechanic- C17
# 3        3                                     Data Scientist
# 4        4                                   Python Developer
# ..     ...                                                ...
# 795    795                                     Java Developer
# 796    796                          Junior Frontend Developer
# 797    797                           Website Development Lead
# 798    798                           IT Application Developer
# 799    799                              Operation Engineer-12
#
#                                                job_url  \
# 0    https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1    https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# ...

# %%
df4 = df[['city', 'State']]

# %%
df4
# Out:
#           city         State
# 0    Bengaluru     Karnataka
# 1    Bengaluru     Karnataka
# 2       Mumbai  Maharashtra
# 3    Bengaluru     Karnataka
# 4    Bengaluru     Karnataka
# ..         ...           ...
# 795  Bengaluru     Karnataka
# 796       Pune   Maharashtra
# 797       Pune   Maharashtra
# 798  Bengaluru     Karnataka
# 799  Bengaluru     Karnataka
#
# [800 rows x 2 columns]
